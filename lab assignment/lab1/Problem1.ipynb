# %% [markdown]
# # Problem 1

# %%
print("Problem 1. Part 1.");
print("a=6 , b=0, m=11 ");
print ("---------------");

for seed in range(11): #range(11) means 0<=seed and seed<11
    print("Seed value:", end=" ");
    print (seed);
    print ("Sequence :", end=" ");
    a=6; b=0; m=11;
    x=seed;
    trace_sequence=[-1]*13;
    
    period_length=0;
    for _ in range(13):
        if trace_sequence[x]!=-1:
            break;
        else:
            trace_sequence[x]=_;
            period_length+=1;
            x=(a*x+b)%m;
            print(x, end=" ");
            
    print("\nPeriod-Length :",end=" ");
    print(period_length);
    print("--------------------")
    
print("-----------------------------x------------------------------------------");
    
print("Problem 1. Part 2." );
print("a=3 , b=0, m=11 ");
print ("---------------");

for seed in range(11): #range(11) means 0<=seed and seed<11
    print("Seed value:", end=" ");
    print (seed);
    print ("Sequence :", end=" ");
    a=3; b=0; m=11;
    x=seed;
    trace_sequence=[-1]*13;
    
    period_length=0;
    for _ in range(13):
        if trace_sequence[x]!=-1:
            break;
        else:
            trace_sequence[x]=_;
            period_length+=1;
            x=(a*x+b)%m;
            print(x, end=" ");
            
    print("\nPeriod-Length :",end=" ");
    print(period_length);
    print("-----------------");
    
print("-----------------------------x------------------------------------------");
# Out:
# Problem 1. Part 1.
# a=6 , b=0, m=11
# ---------------
# Seed value: 0
# Sequence : 0
# Period-Length : 1
# --------------------
# Seed value: 1
# Sequence : 6 3 7 9 10 5 8 4 2 1
# Period-Length : 10
# --------------------
# Seed value: 2
# Sequence : 1 6 3 7 9 10 5 8 4 2
# Period-Length : 10
# --------------------
# Seed value: 3
# Sequence : 7 9 10 5 8 4 2 1 6 3
# Period-Length : 10
# --------------------
# Seed value: 4
# Sequence : 2 1 6 3 7 9 10 5 8 4
# Period-Length : 10
# --------------------
# Seed value: 5
# Sequence : 8 4 2 1 6 3 7 9 10 5
# Period-Length : 10
# --------------------
# Seed value: 6
# Sequence : 3 7 9 10 5 8 4 2 1 6
# Period-Length : 10
# --------------------
# Seed value: 7
# Sequence : 9 10 5 8 4 2 1 6 3 7
# Period-Length : 10
# --------------------
# Seed value: 8
# Sequence : 4 2 1 6 3 7 9 10 5 8
# Period-Length : 10
# --------------------
# Seed value: 9
# Sequence : 10 5 8 4 2 1 6 3 7 9
# Period-Length : 10
# --------------------
# Seed value: 10
# Sequence : 5 8 4 2 1 6 3 7 9 10
# Period-Length : 10
# --------------------
# -----------------------------x------------------------------------------
# Problem 1. Part 2.
# a=3 , b=0, m=11
# ---------------
# Seed value: 0
# Sequence : 0
# Period-Length : 1
# -----------------
# Seed value: 1
# Sequence : 3 9 5 4 1
# Period-Length : 5
# -----------------
# Seed value: 2
# Sequence : 6 7 10 8 2
# Period-Length : 5
# -----------------
# Seed value: 3
# Sequence : 9 5 4 1 3
# Period-Length : 5
# -----------------
# Seed value: 4
# Sequence : 1 3 9 5 4
# Period-Length : 5
# -----------------
# Seed value: 5
# Sequence : 4 1 3 9 5
# Period-Length : 5
# -----------------
# Seed value: 6
# Sequence : 7 10 8 2 6
# Period-Length : 5
# -----------------
# Seed value: 7
# Sequence : 10 8 2 6 7
# Period-Length : 5
# -----------------
# Seed value: 8
# Sequence : 2 6 7 10 8
# Period-Length : 5
# -----------------
# Seed value: 9
# Sequence : 5 4 1 3 9
# Period-Length : 5
# -----------------
# Seed value: 10
# Sequence : 8 2 6 7 10
# Period-Length : 5
# -----------------
# -----------------------------x------------------------------------------
